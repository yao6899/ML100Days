# %%
import numpy as np

# %%
import pandas as pd

# %%
ts=pd.Series(np.random.randn(200),index=pd.date_range('1/1/2020',periods=200))
ts=ts.cumsum()
print(ts)
ts.plot()
# Out:
# 2020-01-01    -1.058821
# 2020-01-02     0.563589
# 2020-01-03     0.361101
# 2020-01-04    -0.662721
# 2020-01-05    -1.236569
# 2020-01-06    -1.149911
# 2020-01-07    -0.323068
# 2020-01-08    -0.649890
# 2020-01-09    -4.561705
# 2020-01-10    -6.161373
# 2020-01-11    -4.974285
# 2020-01-12    -3.865980
# 2020-01-13    -5.401965
# 2020-01-14    -6.471761
# 2020-01-15    -6.371003
# 2020-01-16    -7.512443
# 2020-01-17    -8.159883
# 2020-01-18    -7.175408
# 2020-01-19    -6.110525
# 2020-01-20    -7.794001
# 2020-01-21    -8.106319
# 2020-01-22    -6.944680
# 2020-01-23    -8.360700
# 2020-01-24    -8.500998
# 2020-01-25    -6.431542
# 2020-01-26    -5.973653
# 2020-01-27    -7.209374
# 2020-01-28    -8.954575
# 2020-01-29    -8.774434
# 2020-01-30   -11.357987
#                 ...
# 2020-06-19   -23.733635
# 2020-06-20   -22.944432
# 2020-06-21   -23.677927
# 2020-06-22   -21.877303
# 2020-06-23   -22.259667
# 2020-06-24   -21.682017
# 2020-06-25   -20.975163
# ...

# %%
#如果資料有多個欄位時，也可以同時話出多筆資料在同一張圖上。

# %%
df=pd.DataFrame(np.random.randn(200,3),index=pd.date_range('1/1/2020',periods=200),columns=['A','B','C'])

# %%
df2=df.cumsum() #累積數值
df
# Out:
#                    A         B         C
# 2020-01-01 -0.636714 -2.136897  0.735813
# 2020-01-02 -0.586436 -0.200544  0.561253
# 2020-01-03 -0.011570 -0.127841 -0.831786
# 2020-01-04 -0.886784 -0.277599 -1.145048
# 2020-01-05 -2.034344  0.146751  0.758974
# 2020-01-06  0.258559 -0.706501 -0.333811
# 2020-01-07  0.549256  0.843852 -1.090724
# 2020-01-08 -1.488229  0.106755  0.098406
# 2020-01-09  0.385258  0.455395  1.675484
# 2020-01-10  2.197552  1.255754  0.681957
# 2020-01-11 -1.012974  1.345561 -1.737784
# 2020-01-12 -2.256592 -0.021909  0.407405
# 2020-01-13  0.215780  0.141327 -0.122572
# 2020-01-14 -0.388571  0.568719  0.730433
# 2020-01-15  0.855338 -1.463074 -0.542980
# 2020-01-16 -0.012487 -0.994061 -1.138768
# 2020-01-17 -1.188389 -0.646486 -0.472120
# 2020-01-18  0.223025 -1.669103 -0.430070
# 2020-01-19 -0.873741 -0.798493 -0.474018
# 2020-01-20  1.526794 -0.189448 -0.217479
# 2020-01-21 -0.738873  0.333969  0.686030
# 2020-01-22  1.003029  0.160314 -2.006314
# ...

# %%
df2
# Out:
#                     A          B          C
# 2020-01-01  -0.636714  -2.136897   0.735813
# 2020-01-02  -1.223149  -2.337441   1.297066
# 2020-01-03  -1.234719  -2.465282   0.465280
# 2020-01-04  -2.121503  -2.742882  -0.679768
# 2020-01-05  -4.155847  -2.596131   0.079206
# 2020-01-06  -3.897288  -3.302632  -0.254605
# 2020-01-07  -3.348032  -2.458780  -1.345330
# 2020-01-08  -4.836261  -2.352025  -1.246924
# 2020-01-09  -4.451003  -1.896630   0.428561
# 2020-01-10  -2.253450  -0.640876   1.110518
# 2020-01-11  -3.266425   0.704685  -0.627266
# 2020-01-12  -5.523016   0.682776  -0.219861
# 2020-01-13  -5.307237   0.824103  -0.342432
# 2020-01-14  -5.695808   1.392822   0.388000
# 2020-01-15  -4.840470  -0.070252  -0.154980
# 2020-01-16  -4.852956  -1.064313  -1.293748
# 2020-01-17  -6.041346  -1.710799  -1.765868
# 2020-01-18  -5.818320  -3.379902  -2.195938
# 2020-01-19  -6.692062  -4.178394  -2.669956
# 2020-01-20  -5.165268  -4.367842  -2.887435
# ...

# %%
df=pd.Series(np.random.rand(4),index=
             ["A","B","C","D"],name="title")

# %%
print(df)
# Out:
# A    0.507551
# B    0.409335
# C    0.002041
# D    0.885948
# Name: title, dtype: float64

# %%
df.plot.pie()

# %%
df=pd.DataFrame(np.random.rand(10,2),columns=["A","B"])
print(df)
df.plot.bar()
# Out:
#           A         B
# 0  0.920356  0.577679
# 1  0.105226  0.388348
# 2  0.632525  0.819128
# 3  0.249131  0.597295
# 4  0.378634  0.846266
# 5  0.146060  0.481067
# 6  0.133577  0.453051
# 7  0.015043  0.094500
# 8  0.614279  0.631057
# 9  0.105931  0.175932

# %%
df.plot.bar(stacked=True)

# %%
df=pd.DataFrame(np.random.rand(10,2),columns=["A","B"])

# %%
print(df)
# Out:
#           A         B
# 0  0.757023  0.558103
# 1  0.704326  0.058071
# 2  0.706831  0.359156
# 3  0.866222  0.350230
# 4  0.313281  0.197827
# 5  0.887043  0.800956
# 6  0.470370  0.976801
# 7  0.890566  0.426904
# 8  0.963475  0.798051
# 9  0.437286  0.012762

# %%
df.boxplot()

# %%
df=pd.DataFrame(np.random.rand(10,2),columns=["A","B"])
print(df)
df.plot.scatter(x='A',y='B')
# Out:
#           A         B
# 0  0.014716  0.190044
# 1  0.400907  0.974919
# 2  0.613163  0.455985
# 3  0.877698  0.976921
# 4  0.208692  0.727588
# 5  0.414774  0.668201
# 6  0.318342  0.128439
# 7  0.522051  0.253187
# 8  0.816449  0.157271
# 9  0.673311  0.047695

# %%
#---------作業區---------
#題目 : 將資料夾中 boston.csv 讀進來，並用圖表分析欄位。

#畫出箱型圖，並判斷哪個欄位的中位數在 300~400 之間？
#畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係？

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv('boston_hw12.csv')
data
# Out:
#      key      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 0      1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0
# 1      2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0
# 2      3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0
# 3      4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0
# 4      5   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0
# 5      6   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0
# 6      7   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0
# 7      8   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0
# 8      9   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0
# 9     10   0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0
# 10    11   0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267   5.0
# 11    12   0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509   5.0
# ...

# %%
data.boxplot() #看圖得知TAX的中位數在300-400間

# %%
data.plot.scatter(x='NOX',y='DIS') #呈現負相關
