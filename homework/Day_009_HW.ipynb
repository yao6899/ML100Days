# %%
import pandas as pd

# %%
iris_data=pd.read_csv('iris.csv')

# %%
iris_data
# Out:
#      sepal length  sepal width  petal length  petal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# 5             5.4          3.9           1.7          0.4       0
# 6             4.6          3.4           1.4          0.3       0
# 7             5.0          3.4           1.5          0.2       0
# 8             4.4          2.9           1.4          0.2       0
# 9             4.9          3.1           1.5          0.1       0
# 10            5.4          3.7           1.5          0.2       0
# 11            4.8          3.4           1.6          0.2       0
# 12            4.8          3.0           1.4          0.1       0
# ...

# %%
iris_data=pd.read_csv('iris.csv',usecols=['petal length','petal width','target'])

# %%
iris_data
# Out:
#      petal length  petal width  target
# 0             1.4          0.2       0
# 1             1.4          0.2       0
# 2             1.3          0.2       0
# 3             1.5          0.2       0
# 4             1.4          0.2       0
# 5             1.7          0.4       0
# 6             1.4          0.3       0
# 7             1.5          0.2       0
# 8             1.4          0.2       0
# 9             1.5          0.1       0
# 10            1.5          0.2       0
# 11            1.6          0.2       0
# 12            1.4          0.1       0
# 13            1.1          0.1       0
# 14            1.2          0.2       0
# 15            1.5          0.4       0
# 16            1.3          0.4       0
# 17            1.4          0.3       0
# 18            1.7          0.3       0
# 19            1.5          0.3       0
# 20            1.7          0.2       0
# 21            1.5          0.4       0
# 22            1.0          0.2       0
# ...

# %%
iris_data=pd.read_csv('iris.csv',header=0,names=['featrue1','featrue2','featrue3','featrue4','target'])

# %%
iris_data
# Out:
#      featrue1  featrue2  featrue3  featrue4  target
# 0         4.9       3.0       1.4       0.2       0
# 1         4.7       3.2       1.3       0.2       0
# 2         4.6       3.1       1.5       0.2       0
# 3         5.0       3.6       1.4       0.2       0
# 4         5.4       3.9       1.7       0.4       0
# 5         4.6       3.4       1.4       0.3       0
# 6         5.0       3.4       1.5       0.2       0
# 7         4.4       2.9       1.4       0.2       0
# 8         4.9       3.1       1.5       0.1       0
# 9         5.4       3.7       1.5       0.2       0
# 10        4.8       3.4       1.6       0.2       0
# 11        4.8       3.0       1.4       0.1       0
# 12        4.3       3.0       1.1       0.1       0
# 13        5.8       4.0       1.2       0.2       0
# 14        5.7       4.4       1.5       0.4       0
# 15        5.4       3.9       1.3       0.4       0
# 16        5.1       3.5       1.4       0.3       0
# ...

# %%
iris_data.to_csv('my_iris.csv')

# %%
data=pd.read_excel('data.xls')
data
# Out:
#      sepal length  sepal width  petal length  petal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# 5             5.4          3.9           1.7          0.4       0
# 6             4.6          3.4           1.4          0.3       0
# 7             5.0          3.4           1.5          0.2       0
# 8             4.4          2.9           1.4          0.2       0
# 9             4.9          3.1           1.5          0.1       0
# 10            5.4          3.7           1.5          0.2       0
# 11            4.8          3.4           1.6          0.2       0
# 12            4.8          3.0           1.4          0.1       0
# ...

# %%
#-------作業區--------

# %%
import pandas as pd

# %%
data_test=pd.read_csv('boston.csv',header=0,usecols=['CHAS','NOX','RM'])

# %%
data_test
# Out:
#      CHAS    NOX     RM
# 0     0.0  0.538  6.575
# 1     0.0  0.469  6.421
# 2     0.0  0.469  7.185
# 3     0.0  0.458  6.998
# 4     0.0  0.458  7.147
# 5     0.0  0.458  6.430
# 6     0.0  0.524  6.012
# 7     0.0  0.524  6.172
# 8     0.0  0.524  5.631
# 9     0.0  0.524  6.004
# 10    0.0  0.524  6.377
# 11    0.0  0.524  6.009
# 12    0.0  0.524  5.889
# 13    0.0  0.538  5.949
# 14    0.0  0.538  6.096
# 15    0.0  0.538  5.834
# 16    0.0  0.538  5.935
# 17    0.0  0.538  5.990
# 18    0.0  0.538  5.456
# 19    0.0  0.538  5.727
# 20    0.0  0.538  5.570
# 21    0.0  0.538  5.965
# 22    0.0  0.538  6.142
# 23    0.0  0.538  5.813
# 24    0.0  0.538  5.924
# 25    0.0  0.538  5.599
# 26    0.0  0.538  5.813
# 27    0.0  0.538  6.047
# 28    0.0  0.538  6.495
# 29    0.0  0.538  6.674
# ..    ...    ...    ...
# 476   0.0  0.614  6.484
# 477   0.0  0.614  5.304
# 478   0.0  0.614  6.185
# 479   0.0  0.614  6.229
# 480   0.0  0.532  6.242
# 481   0.0  0.532  6.750
# ...

# %%
data_test.to_excel('my_data_test.xlsx',sheet_name='boston')

# %%
#---解答----
boston = pd.read_csv('boston.csv',usecols=['CHAS','NOX','RM'])

# %%
boston.to_excel('hw_boston.xlsx')
